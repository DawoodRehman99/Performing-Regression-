# %% [markdown]
# Importing Required Libraries

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
from sklearn import metrics
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# Loading Dataset

# %%
data=pd.read_csv("Housing.csv")
data
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000  7420         4          2        3      yes        no       no
# 1    12250000  8960         4          4        4      yes        no       no
# 2    12250000  9960         3          2        2      yes        no      yes
# 3    12215000  7500         4          2        2      yes        no      yes
# 4    11410000  7420         4          1        2      yes       yes      yes
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 540   1820000  3000         2          1        1      yes        no      yes
# 541   1767150  2400         3          1        1       no        no       no
# 542   1750000  3620         2          1        1      yes        no       no
# 543   1750000  2910         3          1        1       no        no       no
# 544   1750000  3850         3          1        2      yes        no       no
#
# ...

# %% [markdown]
# Using LabelEncoder() To convert multiple categorical columns to numeric values

# %%
# Example categorical columns
categorical_columns = ['mainroad', 'guestroom',"basement","hotwaterheating","airconditioning","prefarea","furnishingstatus"]


#Initialize Label Encoder()
le = LabelEncoder()

#apply label Encoder() by Loop
for column in categorical_columns:
        data[column] = le.fit_transform(data[column])

# %%
print(data)
# Out:
#         price  area  bedrooms  bathrooms  stories  mainroad  guestroom  \
# 0    13300000  7420         4          2        3         1          0
# 1    12250000  8960         4          4        4         1          0
# 2    12250000  9960         3          2        2         1          0
# 3    12215000  7500         4          2        2         1          0
# 4    11410000  7420         4          1        2         1          1
# ..        ...   ...       ...        ...      ...       ...        ...
# 540   1820000  3000         2          1        1         1          0
# 541   1767150  2400         3          1        1         0          0
# 542   1750000  3620         2          1        1         1          0
# 543   1750000  2910         3          1        1         0          0
# 544   1750000  3850         3          1        2         1          0
#
#      basement  hotwaterheating  airconditioning  parking  prefarea  \
# ...

# %% [markdown]
# Some Preprocessing step.

# %%
data.shape
# Out:
# (545, 13)

# %%
data.columns
# Out:
# Index(['price', 'area', 'bedrooms', 'bathrooms', 'stories', 'mainroad',
#        'guestroom', 'basement', 'hotwaterheating', 'airconditioning',
#        'parking', 'prefarea', 'furnishingstatus'],
#       dtype='object')

# %%
data.isnull().sum()
# Out:
# price               0
# area                0
# bedrooms            0
# bathrooms           0
# stories             0
# mainroad            0
# guestroom           0
# basement            0
# hotwaterheating     0
# airconditioning     0
# parking             0
# prefarea            0
# furnishingstatus    0
# dtype: int64

# %%
data.describe()
# Out:
#               price          area    bedrooms   bathrooms     stories  \
# count  5.450000e+02    545.000000  545.000000  545.000000  545.000000
# mean   4.766729e+06   5150.541284    2.965138    1.286239    1.805505
# std    1.870440e+06   2170.141023    0.738064    0.502470    0.867492
# min    1.750000e+06   1650.000000    1.000000    1.000000    1.000000
# 25%    3.430000e+06   3600.000000    2.000000    1.000000    1.000000
# 50%    4.340000e+06   4600.000000    3.000000    1.000000    2.000000
# 75%    5.740000e+06   6360.000000    3.000000    2.000000    2.000000
# max    1.330000e+07  16200.000000    6.000000    4.000000    4.000000
#
#          mainroad   guestroom    basement  hotwaterheating  airconditioning  \
# count  545.000000  545.000000  545.000000       545.000000       545.000000
# mean     0.858716    0.177982    0.350459         0.045872         0.315596
# std      0.348635    0.382849    0.477552         0.209399         0.465180
# ...

# %% [markdown]
# For Aesthetic Look

# %%
sns.set_style("whitegrid")

# %% [markdown]
# Scatter Plot Of Area vs Price

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x="area", y="price", data=data, hue="bedrooms", palette='viridis')
plt.title('Area vs Price')
plt.xlabel('Area (sq ft)')
plt.ylabel('Price')
plt.legend(title='Bedrooms')
plt.show()

# %% [markdown]
# Distribution Plot of Price

# %%
plt.figure(figsize=(12, 7))
sns.histplot(data['price'], bins=30, kde=True, color='blue', edgecolor='black')
plt.title('Distribution of House Prices', fontsize=20, weight='bold')
plt.xlabel('Price', fontsize=15)
plt.ylabel('Frequency', fontsize=15)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)

# Adding a grid
plt.grid(True, linestyle='--', alpha=0.7)

# Display the plot
plt.show()

# %% [markdown]
# Count Plot of Bedrooms

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x='bedrooms', data=data, palette='viridis')
plt.title('Number of Bedrooms')
plt.xlabel('Bedrooms')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# Count plot of Bathrooms

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x='bathrooms', data=data, palette='viridis')
plt.title('Number of Bathrooms')
plt.xlabel('Bathrooms')
plt.ylabel('Count')
plt.show()

# %%
House_features = ['price','area','bedrooms','bathrooms']
sns.pairplot(data[House_features])
plt.show()

# %% [markdown]
# Heat Map for Represent the Relationship.

# %%
correlation_matrix = data.corr()
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.show()

# %% [markdown]
# Now Split Dependent and Independent Variable.

# %%
#independent and contains all the columns
x=data.drop('price', axis=1)
x
# Out:
#      area  bedrooms  bathrooms  stories  mainroad  guestroom  basement  \
# 0    7420         4          2        3         1          0         0
# 1    8960         4          4        4         1          0         0
# 2    9960         3          2        2         1          0         1
# 3    7500         4          2        2         1          0         1
# 4    7420         4          1        2         1          1         1
# ..    ...       ...        ...      ...       ...        ...       ...
# 540  3000         2          1        1         1          0         1
# 541  2400         3          1        1         0          0         0
# 542  3620         2          1        1         1          0         0
# 543  2910         3          1        1         0          0         0
# 544  3850         3          1        2         1          0         0
#
#      hotwaterheating  airconditioning  parking  prefarea  furnishingstatus
# ...

# %%
#dependent
y=data["price"]
y
# Out:
# 0      13300000
# 1      12250000
# 2      12250000
# 3      12215000
# 4      11410000
#          ...
# 540     1820000
# 541     1767150
# 542     1750000
# 543     1750000
# 544     1750000
# Name: price, Length: 545, dtype: int64

# %% [markdown]
# Split Dataset into Training and Testing

# %%
x_train, x_test, y_train, y_test =train_test_split(x, y, test_size=0.2, random_state =42)

# %% [markdown]
# Feature Scaling on dependent variables

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

# %% [markdown]
# ### Implementing Linear Regression Model.

# %%
lr = LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %% [markdown]
# lets Predict the test set Result

# %%
y_pred = lr.predict(x_test)

# %% [markdown]
# #### Linear Regression Performance.

# %%
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, y_pred)

# %%
print("Linear Regression ")
print(f"Mean Absolute Error (MAE): {mae}")
print(f"Mean Squared Error (MSE): {mse}")
print(f"Root Mean Squared Error (RMSE): {rmse}")
print(f"R-squared (R²): {r2}")
# Out:
# Linear Regression
# Mean Absolute Error (MAE): 979679.6912959908
# Mean Squared Error (MSE): 1771751116594.041
# Root Mean Squared Error (RMSE): 1331071.4167895128
# R-squared (R²): 0.6494754192267792

# %% [markdown]
# Now Visualizing the Result

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x=y_test, y=y_pred)
sns.regplot(x=y_test, y=y_pred, scatter=False, color='red', label='Best Fit Line')
plt.xlabel('Actual Prices')
plt.ylabel('Predicted Prices')
plt.title('Actual vs Predicted Prices (Linear Regression)')
plt.show()

# %% [markdown]
# ## Now Using Decision Tree.

# %%
from sklearn.tree import DecisionTreeRegressor
dtree=DecisionTreeRegressor()

# %%
dtree.fit(x_train, y_train)
# Out:
# DecisionTreeRegressor()

# %%
y_pred=dtree.predict(x_test)

# %% [markdown]
# #### Decision Tree Performance.

# %%
Mae = mean_absolute_error(y_test, y_pred)
Mse = mean_squared_error(y_test, y_pred)
Rmse = np.sqrt(mse)
R2 = r2_score(y_test, y_pred)

# %%
print("Decision Tree ")
print(f"Mean Absolute Error (MAE): {Mae}")
print(f"Mean Squared Error (MSE): {Mse}")
print(f"Root Mean Squared Error (RMSE): {Rmse}")
print(f"R-squared (R²): {R2}")
# Out:
# Decision Tree
# Mean Absolute Error (MAE): 1259807.3394495412
# Mean Squared Error (MSE): 3053872403669.7246
# Root Mean Squared Error (RMSE): 1331071.4167895128
# R-squared (R²): 0.39581957420235625

# %% [markdown]
# ### Now Random Forest Regression Alogrothm.

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
model = RandomForestRegressor(n_estimators=100)
model.fit(x_train, y_train)
# Out:
# RandomForestRegressor()

# %%
y_pred = model.predict(x_test)

# %% [markdown]
# ####  Random forest Regression Performance

# %%
MAE = mean_absolute_error(y_test, y_pred)
MSE = mean_squared_error(y_test, y_pred)
RMSE = np.sqrt(mse)
R_2 = r2_score(y_test, y_pred)

# %%
print("Random Forest Tree ")
print(f"Mean Absolute Error (MAE): {MAE}")
print(f"Mean Squared Error (MSE): {MSE}")
print(f"Root Mean Squared Error (RMSE): {RMSE}")
print(f"R-squared (R²): {R_2}")
# Out:
# Random Forest Tree
# Mean Absolute Error (MAE): 991819.0397553516
# Mean Squared Error (MSE): 1832806911473.3853
# Root Mean Squared Error (RMSE): 1331071.4167895128
# R-squared (R²): 0.6373960945951122

# %% [markdown]
# ### NOW SVR Algorithm..

# %%
from sklearn.svm import SVR
svr = SVR(kernel='rbf') 
svr.fit(x_train, y_train)
# Out:
# SVR()

# %%
y_pred = model.predict(x_test)

# %%
mAe = mean_absolute_error(y_test, y_pred)
mSe = mean_squared_error(y_test, y_pred)
rMSe = np.sqrt(mse)
R1_2 = r2_score(y_test, y_pred)
print("SVR")
print(f"Mean Absolute Error (MAE): {mAe}")
print(f"Mean Squared Error (MSE): {mSe}")
print(f"Root Mean Squared Error (RMSE): {rMSe}")
print(f"R-squared (R²): {R1_2}")
# Out:
# SVR
# Mean Absolute Error (MAE): 991819.0397553516
# Mean Squared Error (MSE): 1832806911473.3853
# Root Mean Squared Error (RMSE): 1331071.4167895128
# R-squared (R²): 0.6373960945951122

# %% [markdown]
# ### GradientBoostingRegressor Algorithm

# %%
from sklearn.ensemble import GradientBoostingRegressor

# %%
gbr = GradientBoostingRegressor(n_estimators=100, learning_rate=0.1, max_depth=3, random_state=42)
gbr.fit(x_train, y_train)
# Out:
# GradientBoostingRegressor(random_state=42)

# %%
y_pred = gbr.predict(x_test)

# %%
MAe = mean_absolute_error(y_test, y_pred)
MSe = mean_squared_error(y_test, y_pred)
RMSe = np.sqrt(mse)
R = r2_score(y_test, y_pred)
print("GradientBoostingRegressor")
print(f"Mean Absolute Error (MAE): {MAe}")
print(f"Mean Squared Error (MSE): {MSe}")
print(f"Root Mean Squared Error (RMSE): {RMSe}")
print(f"R-squared (R²): {R}")
# Out:
# GradientBoostingRegressor
# Mean Absolute Error (MAE): 964058.8730464154
# Mean Squared Error (MSE): 1694870370248.4102
# Root Mean Squared Error (RMSE): 1331071.4167895128
# R-squared (R²): 0.6646855642239725

# %% [markdown]
# ### BEST PERFORMING?

# %%
print("")
print("Linear Regression ")
print(f"Mean Absolute Error (MAE): {mae}")
print(f"Mean Squared Error (MSE): {mse}")
print(f"Root Mean Squared Error (RMSE): {rmse}")
print(f"R-squared (R²): {r2}")
print("")
print("Decision Tree ")
print(f"Mean Absolute Error (MAE): {Mae}")
print(f"Mean Squared Error (MSE): {Mse}")
print(f"Root Mean Squared Error (RMSE): {Rmse}")
print(f"R-squared (R²): {R2}")
print("")
print("Random Forest Tree ")
print(f"Mean Absolute Error (MAE): {MAE}")
print(f"Mean Squared Error (MSE): {MSE}")
print(f"Root Mean Squared Error (RMSE): {RMSE}")
print(f"R-squared (R²): {R_2}")
print("")
print("SVR")
print(f"Mean Absolute Error (MAE): {MAE}")
print(f"Mean Squared Error (MSE): {MSE}")
print(f"Root Mean Squared Error (RMSE): {RMSE}")
print(f"R-squared (R²): {R_2}")
print("")
print("GradientBoostingRegressor")
print(f"Mean Absolute Error (MAE): {MAe}")
print(f"Mean Squared Error (MSE): {MSe}")
print(f"Root Mean Squared Error (RMSE): {RMSe}")
print(f"R-squared (R²): {R}")
# Out:
# Linear Regression
# Mean Absolute Error (MAE): 979679.6912959908
# Mean Squared Error (MSE): 1771751116594.041
# Root Mean Squared Error (RMSE): 1331071.4167895128
# R-squared (R²): 0.6494754192267792
#
# Decision Tree
# Mean Absolute Error (MAE): 1259807.3394495412
# Mean Squared Error (MSE): 3053872403669.7246
# Root Mean Squared Error (RMSE): 1331071.4167895128
# R-squared (R²): 0.39581957420235625
#
# Random Forest Tree
# Mean Absolute Error (MAE): 991819.0397553516
# Mean Squared Error (MSE): 1832806911473.3853
# Root Mean Squared Error (RMSE): 1331071.4167895128
# R-squared (R²): 0.6373960945951122
#
# SVR
# Mean Absolute Error (MAE): 991819.0397553516
# Mean Squared Error (MSE): 1832806911473.3853
# Root Mean Squared Error (RMSE): 1331071.4167895128
# R-squared (R²): 0.6373960945951122
#
# GradientBoostingRegressor
# Mean Absolute Error (MAE): 964058.8730464154
# Mean Squared Error (MSE): 1694870370248.4102
# Root Mean Squared Error (RMSE): 1331071.4167895128
# ...

# %% [markdown]
# ### SUMMARY:

# %% [markdown]
# Best Performing Algorithm and
# Gradient Boosting Regressor: It has the best performance with the lowest MAE and highest R² score, indicating it is the most accurate model for this dataset.

# %% [markdown]
# Short Summary:
# Based on the metrics, the Gradient Boosting Regressor is the best-performing algorithm in terms of error reduction and overall predictive power, with an R² score of 0.665 and MAE of 964,058, meaning it explains 66% of the variance in the target variable and has the lowest prediction error. Other models, like Linear Regression and Random Forest, also perform reasonably well but with slightly higher errors and lower variance explanation.
